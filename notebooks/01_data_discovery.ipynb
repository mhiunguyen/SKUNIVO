# %% [markdown]
# # 01 — Data discovery and data quality
#
# This notebook inventories every supported dataset in the repository, profiles schemas and data quality, infers candidate keys and relationships, and writes the requested reports. It does not train or evaluate any machine-learning model and does not generate charts.

# %%
from pathlib import Path
import json
import sys

repo_root = Path.cwd()
if not (repo_root / "notebooks" / "data_discovery_pipeline.py").exists():
    repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root / "notebooks"))

from data_discovery_pipeline import run_discovery

summary = run_discovery()
print(json.dumps(summary, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Outputs
#
# The detailed inventory, data dictionary, quality findings, schema summary, and relationship audit are saved in `reports/`.
