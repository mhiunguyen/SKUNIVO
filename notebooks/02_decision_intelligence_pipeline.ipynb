# %% [markdown]
# # AI Decision Copilot for Product Opportunity and Promotion Prioritization
#
# This notebook runs the modular, explainable two-track prototype. It performs latest-snapshot validation, peer-normalized scoring, shop-grouped cross-validation, robustness analysis, recommendation generation, and proposal artifact creation. It does not forecast transactional demand or estimate causal promotion lift.

# %%
from pathlib import Path
import json
import sys

repo_root = Path.cwd()
if not (repo_root / "src" / "run_pipeline.py").exists():
    repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root))

from src.run_pipeline import run_pipeline

summary = run_pipeline()
print(json.dumps(summary, ensure_ascii=False, indent=2, default=str))

# %% [markdown]
# ## Output boundary
#
# Recommendations are decision-support priorities based on observed marketplace context. They are not guarantees, causal lift estimates, revenue forecasts, profit optimization, ROAS calculations, customer predictions, or inventory recommendations.
