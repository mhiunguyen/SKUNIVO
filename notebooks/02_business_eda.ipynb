# %% [markdown]
# # 02 — Business exploratory data analysis
#
# This notebook performs product, pricing, promotion, shop, category, official-status, country, and relationship analysis. It generates business insights and charts without building a machine-learning model.

# %%
from pathlib import Path
import json
import sys

repo_root = Path.cwd()
if not (repo_root / "notebooks" / "business_eda_pipeline.py").exists():
    repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root / "notebooks"))

from business_eda_pipeline import run_business_eda

summary = run_business_eda()
print(json.dumps(summary, ensure_ascii=False, indent=2))

# %% [markdown]
# ## Outputs
#
# The complete narrative report, insight register, metric table, and chart files are saved under `reports/`.
